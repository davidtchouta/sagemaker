# %%
import sagemaker 
import boto3 
from sagemaker.amazon.amazon_estimator import get_image_uri 
from sagemaker.session import s3_input, Session

# %%
#bucket_name= 'sagemaker-insurance-predict-bill' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET 
bucket_name = 'bucket-david-predict-insurance' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET 
my_region = boto3.session.Session().region_name # set the region of the instance 
print(my_region)
print(bucket_name)
# Out:
# eu-west-3
# bucket-david-predict-insurance

# %%
import boto3

# Votre nom de bucket et la région souhaitée
#bucket_name = 'bucket-david-predict-insurance'
my_region = 'eu-west-3'

s3 = boto3.resource('s3')
try:
    if my_region == 'eu-west-3':
        s3.create_bucket(Bucket=bucket_name,
                         CreateBucketConfiguration={
                             'LocationConstraint': my_region
                         })
        print('S3 bucket created successfully')
except Exception as e:
    print('S3 error: ', e)
# Out:
# S3 bucket created successfully

# %%
# set an output path where the trained model will be saved
prefix = 'xgboost-as-a-built-in-algo' 
output_path ='s3://{}/{}/output'.format(bucket_name, prefix) 
print(output_path)
# Out:
# s3://bucket-david-predict-insurance/xgboost-as-a-built-in-algo/output

# %% [markdown]
# Downloading The Dataset And Storing in S3

# %%
import pandas as pd 
import urllib 
import os
try: 
    #urllib.request.urlretrieve ("https://d1.awsstatic.com/tmt/build-train-deploy-machine-learning-model-sagemaker/bank_clean.27f01fbbdf43271788427f3682996ae29ceca05d.csv", "bank_clean.csv") 
    from pycaret.datasets import get_data
    data = get_data('insurance')
    print('Success: downloaded data.csv.') 
    print(os.getcwd())
except Exception as e: 
    print('Data load error: ',e) 
try: 
    model_data = pd.read_csv('insurance.csv') 
    print('Success: Data loaded into dataframe.') 
except Exception as e: 
    print('Data load error: ',e)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# Success: downloaded data.csv.
# /home/sagemaker-user
# Success: Data loaded into dataframe.

# %%
# !ls
# Out:
# data.csv		 logs.log	 test.csv
# insurance-predict.ipynb  model.tar.gz	 train.csv
# insurance.csv		 test-sgm.ipynb  xgboost-model

# %%
mdata=model_data.copy()
mdata
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
mdata['sex'] = mdata['sex'].map({'female': 0, 'male': 1})
mdata['smoker'] = mdata['smoker'].map({'no': 0, 'yes': 1})
mdata['region'] = mdata['region'].map({'southeast': 0, 'northwest': 1, 'southwest': 2, 'northeast': 3})
mdata
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       2  16884.92400
# 1      18    1  33.770         1       0       0   1725.55230
# 2      28    1  33.000         3       0       0   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       3   2205.98080
# 1335   18    0  36.850         0       0       0   1629.83350
# 1336   21    0  25.800         0       0       2   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
### Train Test split 
import numpy as np 
train_data, test_data = np.split(mdata.sample(frac=1, random_state=1729), [int(0.7 * len(mdata))]) 
print(train_data.shape, test_data.shape)
# Transformer les données avant d'utiliser un modèle

test_data
# Out:
# (936, 7) (402, 7)
#       age  sex     bmi  children  smoker  region      charges
# 585    33    0  28.270         1       0       0   4779.60230
# 831    36    0  25.840         0       0       1   5266.36560
# 739    29    1  35.500         2       1       2  44585.45587
# 696    53    0  32.300         2       0       3  29186.48236
# 174    24    0  33.345         0       0       1   2855.43755
# ...   ...  ...     ...       ...     ...     ...          ...
# 315    52    1  33.250         0       0       3   9722.76950
# 857    25    1  24.130         0       1       1  15817.98570
# 1091   55    0  29.830         0       0       3  11286.53870
# 1267   24    1  31.065         0       1       3  34254.05335
# 1126   55    1  29.900         0       0       2  10214.63600
#
# [402 rows x 7 columns]

# %%
### Saving Train And Test Into Buckets 
## We start with Train Data
import os 
train_data.to_csv('train.csv', index=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv') 
s3_input_train = sagemaker.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %%
# Test Data Into Buckets 
test_data.to_csv('test.csv', index=False) 
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'test/test.csv')).upload_file('test.csv') 
s3_input_test = sagemaker.TrainingInput(s3_data='s3://{}/{}/test'.format(bucket_name, prefix), content_type='csv')

# %% [markdown]
# Building Models Xgboot- Inbuilt Algorithm

# %%
# this line automatically looks for the XGBoost image URI and builds an XGBoost container. 
# specify the repo_version depending on your preference. 
container = get_image_uri(boto3.Session().region_name, 'xgboost', repo_version='1.7-1')
# Out:
# WARNING:sagemaker.deprecations:The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %%
# initialize hyperparameters 
hyperparameters = { "max_depth":"5",
                   "eta":"0.2",
                   "gamma":"4",
                   "min_child_weight":"6",
                   "subsample":"0.7",
                   "objective":"reg:squarederror",
                   "num_round":50 }

# %%
# construct a SageMaker estimator that calls the xgboost-container 
estimator = sagemaker.estimator.Estimator(image_uri=container,
                                          hyperparameters=hyperparameters,
                                          role=sagemaker.get_execution_role(),
                                          instance_count=1,
                                          instance_type='ml.m5.2xlarge',
                                          #volume_size=3,  # 3 GB
                                          output_path=output_path,
                                          #framework_version="1.7-1",  # Note: framework_version is mandatory
                                          use_spot_instances=True,  # Utilisation d'instances Spot pour réduire le coût
                                          max_run=300,
                                          max_wait=600
                                         )

# %%
estimator

# %%
estimator.fit({'train': s3_input_train,'validation': s3_input_test})
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2024-02-11-08-35-39-783
# 2024-02-11 08:35:39 Starting - Starting the training job...
# 2024-02-11 08:35:57 Starting - Preparing the instances for training.........
# 2024-02-11 08:37:28 Downloading - Downloading input data...
# 2024-02-11 08:37:53 Downloading - Downloading the training image...
# 2024-02-11 08:38:39 Training - Training image download completed. Training in progress....
# 2024-02-11 08:39:09 Uploading - Uploading generated training model[2024-02-11 08:39:00.754 ip-10-0-185-86.eu-west-3.compute.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-02-11 08:39:00.777 ip-10-0-185-86.eu-west-3.compute.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-02-11:08:39:01:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-02-11:08:39:01:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2024-02-11:08:39:01:INFO] No GPUs detected (normal if no gpus installed)
# [2024-02-11:08:39:01:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-02-11:08:39:01:INFO] Determined 0 GPU(s) available on the instance.
# [2024-02-11:08:39:01:INFO] Determined delimiter of CSV input is ','
# [2024-02-11:08:39:01:INFO] Determined delimiter of CSV input is ','
# [2024-02-11:08:39:01:INFO] File path /opt/ml/input/data/train of input files
# [2024-02-11:08:39:01:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2024-02-11:08:39:01:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv2307339024278890505
# [2024-02-11:08:39:01:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-02-11:08:39:01:INFO] Determined delimiter of CSV input is ','
# [2024-02-11:08:39:01:INFO] File path /opt/ml/input/data/validation of input files
# [2024-02-11:08:39:01:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2024-02-11:08:39:01:INFO] creating symlink between Path /opt/ml/input/data/validation/test.csv and destination /tmp/sagemaker_xgboost_input_data/test.csv-5618516335177200900
# [2024-02-11:08:39:01:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2024-02-11:08:39:01:INFO] Determined delimiter of CSV input is ','
# [2024-02-11:08:39:01:INFO] Single node training.
# [2024-02-11:08:39:01:INFO] Train matrix has 937 rows and 6 columns
# [2024-02-11:08:39:01:INFO] Validation matrix has 403 rows
# [2024-02-11 08:39:01.213 ip-10-0-185-86.eu-west-3.compute.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024-02-11 08:39:01.213 ip-10-0-185-86.eu-west-3.compute.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2024-02-11 08:39:01.214 ip-10-0-185-86.eu-west-3.compute.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2024-02-11 08:39:01.214 ip-10-0-185-86.eu-west-3.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2024-02-11:08:39:01:INFO] Debug hook created from config
# [0]#011train-rmse:33.24229#011validation-rmse:33.58079
# [2024-02-11 08:39:01.218 ip-10-0-185-86.eu-west-3.compute.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2024-02-11 08:39:01.224 ip-10-0-185-86.eu-west-3.compute.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [1]#011train-rmse:27.07848#011validation-rmse:27.33875
# [2]#011train-rmse:22.14170#011validation-rmse:22.35059
# [3]#011train-rmse:18.17645#011validation-rmse:18.36184
# [4]#011train-rmse:15.19001#011validation-rmse:15.32672
# [5]#011train-rmse:12.77090#011validation-rmse:12.88755
# [6]#011train-rmse:10.91665#011validation-rmse:10.95029
# [7]#011train-rmse:9.54295#011validation-rmse:9.60620
# [8]#011train-rmse:8.47604#011validation-rmse:8.51886
# [9]#011train-rmse:7.68196#011validation-rmse:7.73840
# [10]#011train-rmse:7.06272#011validation-rmse:7.08076
# [11]#011train-rmse:6.57875#011validation-rmse:6.51882
# [12]#011train-rmse:6.28991#011validation-rmse:6.22485
# [13]#011train-rmse:6.11372#011validation-rmse:6.03825
# [14]#011train-rmse:5.93362#011validation-rmse:5.89454
# [15]#011train-rmse:5.79507#011validation-rmse:5.75428
# [16]#011train-rmse:5.67299#011validation-rmse:5.68924
# [17]#011train-rmse:5.53226#011validation-rmse:5.62974
# [18]#011train-rmse:5.41988#011validation-rmse:5.56065
# [19]#011train-rmse:5.34807#011validation-rmse:5.46615
# [20]#011train-rmse:5.21528#011validation-rmse:5.41087
# [21]#011train-rmse:5.09012#011validation-rmse:5.39477
# [22]#011train-rmse:5.05890#011validation-rmse:5.34529
# [23]#011train-rmse:4.98460#011validation-rmse:5.30853
# [24]#011train-rmse:4.91098#011validation-rmse:5.30463
# [25]#011train-rmse:4.84705#011validation-rmse:5.28174
# [26]#011train-rmse:4.76825#011validation-rmse:5.29481
# [27]#011train-rmse:4.69507#011validation-rmse:5.31044
# [28]#011train-rmse:4.60397#011validation-rmse:5.29314
# [29]#011train-rmse:4.56849#011validation-rmse:5.27642
# [30]#011train-rmse:4.48675#011validation-rmse:5.28787
# [31]#011train-rmse:4.44297#011validation-rmse:5.20914
# [32]#011train-rmse:4.39547#011validation-rmse:5.22332
# [33]#011train-rmse:4.35208#011validation-rmse:5.26381
# [34]#011train-rmse:4.28676#011validation-rmse:5.24863
# [35]#011train-rmse:4.28261#011validation-rmse:5.22903
# [36]#011train-rmse:4.24270#011validation-rmse:5.24341
# [37]#011train-rmse:4.19979#011validation-rmse:5.25289
# [38]#011train-rmse:4.16210#011validation-rmse:5.27278
# [39]#011train-rmse:4.11227#011validation-rmse:5.27994
# [40]#011train-rmse:4.06857#011validation-rmse:5.30364
# [41]#011train-rmse:4.04881#011validation-rmse:5.28535
# [42]#011train-rmse:4.01471#011validation-rmse:5.27177
# [43]#011train-rmse:3.96272#011validation-rmse:5.31697
# [44]#011train-rmse:3.92596#011validation-rmse:5.30675
# [45]#011train-rmse:3.81954#011validation-rmse:5.29336
# [46]#011train-rmse:3.78881#011validation-rmse:5.27823
# [47]#011train-rmse:3.75809#011validation-rmse:5.27086
# [48]#011train-rmse:3.73098#011validation-rmse:5.23693
# [49]#011train-rmse:3.71182#011validation-rmse:5.24078
#
# 2024-02-11 08:39:20 Completed - Training job completed
# Training seconds: 112
# Billable seconds: 45
# Managed Spot Training savings: 59.8%

# %%
xgb_predictor = estimator.deploy(initial_instance_count=1,instance_type='ml.m5.2xlarge')
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2024-02-11-08-44-08-065
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2024-02-11-08-44-08-065
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2024-02-11-08-44-08-065
# -----!

# %%
xgb_predictor

# %% [markdown]
# Prediction of the Test Data

# %%
#train_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data))]) 
test_data
#train_data
#test_data.to_csv('test.csv', index=False)
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 585    33    0  28.270         1       0       0   4779.60230
# 831    36    0  25.840         0       0       1   5266.36560
# 739    29    1  35.500         2       1       2  44585.45587
# 696    53    0  32.300         2       0       3  29186.48236
# 174    24    0  33.345         0       0       1   2855.43755
# ...   ...  ...     ...       ...     ...     ...          ...
# 315    52    1  33.250         0       0       3   9722.76950
# 857    25    1  24.130         0       1       1  15817.98570
# 1091   55    0  29.830         0       0       3  11286.53870
# 1267   24    1  31.065         0       1       3  34254.05335
# 1126   55    1  29.900         0       0       2  10214.63600
#
# [402 rows x 7 columns]

# %%
import sagemaker
from sagemaker.serializers import CSVSerializer

# Configurez votre endpoint si nécessaire
endpoint_name = "sagemaker-xgboost-2024-02-11-08-44-08-065"  # Remplacez par le nom de votre endpoint
sagemaker_session = sagemaker.Session()

# Créez un objet Predictor pour votre modèle
xgb_predictor = sagemaker.predictor.Predictor(
    endpoint_name=endpoint_name,
    sagemaker_session=sagemaker_session,
    serializer=CSVSerializer(),  # Spécifiez le serializer pour le type de contenu CSV
)

# Nouvelles données pour la prédiction, déjà converties si nécessaire
#data_csv = "19,female,27.9,0,yes,southwest"
data_csv = "24,0,27.9,1,1,3"  # Assurez-vous que cette chaîne est correctement formatée

# Utilisez l'endpoint pour faire une prédiction avec le bon ContentType
response = xgb_predictor.predict(data_csv)

# Affichez la réponse de la prédiction
print(response)
# Out:
# b'11.769454002380371\n'

# %%
# %pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in ./.conda/envs/pycaretenv/lib/python3.8/site-packages (from xgboost) (1.24.4)
# Requirement already satisfied: scipy in ./.conda/envs/pycaretenv/lib/python3.8/site-packages (from xgboost) (1.10.1)
# Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 7.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Conversion des variables catégorielles
dt=test_data.copy()
dt['sex'] = dt['sex'].map({'female': 0, 'male': 1})
dt['smoker'] = dt['smoker'].map({'no': 0, 'yes': 1})
dt['region'] = dt['region'].map({'southeast': 0, 'northwest': 1, 'southwest': 2, 'northeast': 3})

# Supprimer la colonne 'charges'
dt = dt.drop(columns=['charges'])
print(dt)
# Out:
#       age  sex     bmi  children  smoker  region
# 585    33  NaN  28.270         1     NaN     NaN
# 831    36  NaN  25.840         0     NaN     NaN
# 739    29  NaN  35.500         2     NaN     NaN
# 696    53  NaN  32.300         2     NaN     NaN
# 174    24  NaN  33.345         0     NaN     NaN
# ...   ...  ...     ...       ...     ...     ...
# 315    52  NaN  33.250         0     NaN     NaN
# 857    25  NaN  24.130         0     NaN     NaN
# 1091   55  NaN  29.830         0     NaN     NaN
# 1267   24  NaN  31.065         0     NaN     NaN
# 1126   55  NaN  29.900         0     NaN     NaN
#
# [402 rows x 6 columns]

# %%
import pickle as pkl
import tarfile
import xgboost as xgb

with tarfile.open('model.tar.gz', 'r:gz') as t:
    t.list()  # Affiche la liste des fichiers contenus dans l'archive tar

# Chemin vers le fichier modèle XGBoost extrait
model_file_path = 'xgboost-model'

# Chargement du modèle
with open(model_file_path, 'rb') as file:
    model = pkl.load(file)

# Vérification du modèle chargé
print(model)

# Supprimer la colonne 'charges'
dt=test_data.copy()
dt = dt.drop(columns=['charges'])
#dt = dt.drop(columns=['region'])
print(dt)

# Assurez-vous d'utiliser le DataFrame encodé pour la prédiction
dtest = xgb.DMatrix(dt)
pred = model.predict(dtest)

print(pred)
# Out:
# -rw-r--r-- root/root      71397 2024-02-11 07:40:24 xgboost-model
# <xgboost.core.Booster object at 0x7f28eb6ad2e0>
#       age  sex     bmi  children  smoker  region
# 585    33    0  28.270         1       0       0
# 831    36    0  25.840         0       0       1
# 739    29    1  35.500         2       1       2
# 696    53    0  32.300         2       0       3
# 174    24    0  33.345         0       0       1
